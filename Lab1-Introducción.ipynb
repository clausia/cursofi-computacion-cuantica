# %% [markdown]
# <table style="background-color: transparent;">
#     <tr style="background-color: transparent; text-align:center;">
#         <td width="100%" align="center"><font size="7" color="#f25625">Computación Cuántica</font></td>
#     </tr>
#     <tr style="background-color: transparent; text-align:center;">
#         <td width="100%"><font size="4" color="black">Temas Selectos de Ingeniería en Computación I</font></td>
#     </tr>
#     <tr style="background-color: transparent; text-align:center;">
#         <td width="100%"><font size="4" color="black">2024-2</font></td>
#     </tr>
#     <tr style="background-color: transparent; text-align:center;">
#         <td width="100%"><font size="6" color="#f25625">Laboratorio 1: Introducción</font></td>
#     </tr>
# </table>

# %% [markdown]
# ## Contenido
#
# 1. [Introducción](#1)
#     1. [Computación cuántica, ¿cómo la uso?](#1.1)
#     2. [¿En dónde estamos actualmente?](#1.2)
# 2. [Frameworks para Computación Cuántica](#2)
# 3. [Plataformas con acceso a Hardware Cuántico](#3)
# 4. [Instalación y pruebas con Qiskit](#4)
# 5. [Computadoras SpinQ](#5)
# 6. [Tarea](#6)

# %% [markdown]
# <a id="1"></a>
# # 1. Introducción

# %% [markdown]
# <a id="1.1"></a>
# ## 1.A. Computación cuántica, ¿cómo la uso?

# %% [markdown]
# La computación cuántica es una tecnología de rápido crecimiento que aprovecha las leyes de la mecánica cuántica (como la **superposición**, la **interferencia** y el **entrelazamiento**) para resolver problemas demasiado complejos para las computadoras clásicas. Los dispositivos que realizan cálculos cuánticos se conocen como computadoras cuánticas o hardware cuántico.
#
# De manera análoga a la computación clásica, podemos crear **algoritmos cuánticos** que se ejecutan en estas nuevas computadoras. Actualmente una manera popular de implementar estos algoritmos es con **circuitos cuánticos**, los cuales necesitan **compuertas cuánticas** para definirlos.

# %% [markdown]
# <a id="1.2"></a>
# ## 1.B. ¿En dónde estamos actualmente?

# %% [markdown]
# Las computadoras cuánticas que tenemos hoy en día son demasiado pequeñas (pocos qubits) e inestables para dar una ventaja sobre las computadoras tradicionales.
#
# En un nivel muy simple, hay dos factores que limitan el tamaño de los problemas que pueden resolver las computadoras cuánticas de hoy en día.
#
# El primero es la cantidad de datos que se pueden almacenar y por lo tanto trabajar con estos, que normalmente medimos en qubits. Un **qubit** es un *bit cuántico*. Si no tenemos suficientes qubits, simplemente no podemos almacenar ni operar problemas por encima de cierto tamaño.
#
# El segundo es la tasa de error de nuestra computadora cuántica; crear computadoras cuánticas es un proceso delicado. Las computadoras cuánticas que tenemos ahora son ruidosas, lo que significa que a menudo se equivocan e introducen "*ruido*". El ruido es información inútil que es difícil de distinguir de la información útil.
#
# Por ejemplo, la estimación para factorizar un número muy grande (por ejemplo de 617 dígitos) en menos de un día asume una cantidad de ~20 millones de qubits ruidosos. En el momento de escribir esto (febrero 2024), IBM ha creado una computadora cuántica de 1,121 qubits y tiene como objetivo crear sistemas más robustos en el futuro cercano, sin apresurar la cantidad de qubits. Hay otros algoritmos que creemos que nos darán una ventaja cuántica mucho antes de este hito, ver por ejemplo el artículo recién publicado de IBM: "[Evidence for the utility of quantum computing before fault tolerance](https://www.nature.com/articles/s41586-023-06096-3)" ("Evidencia de la utilidad de la computación cuántica antes de la tolerancia a fallas").
#
# Actualmente, por ejemplo, existen empresas que están invirtiendo en algorimos cuánticos y computación cuántica con el fin de aprovechar esa ventaja.
#
# Afortunadamente, cualquier interesado, puede ejecutar y crear algoritmos cuánticos propios en miras de aprender a usar esta nueva tecnología.

# %% [markdown]
# <a id="2"></a>
# # 2. Frameworks para Computación Cuántica

# %% [markdown]
# Actualmente existen múltiples maneras de hacer computación cuántica, desde simulaciones en computadoras clásicas, hasta poder aceder a computadoras cuánticas reales a través de la nube.
#
# Para programar una computadora cuántica necesitamos de un lenguaje de programación; sin embargo, la mayoría ha optado por usar lenguajes ya existentes y crear un framework para extender la funcionalidad de los mismos. A continuación veremos algunos de estos.

# %% [markdown]
# <a id="2.1"></a>
# ## 2.1. Qiskit

# %% [markdown]
# Desarrollado por IBM Quantum, Qiskit es un SDK de código abierto para computación cuántica que permite escribir, simular y ejecutar programas cuánticos en hardware real y simuladores. Corre bajo el lenguaje de programación Python
#
# - Página principal: https://www.ibm.com/quantum/qiskit
# - Tutoriales: https://learning.quantum.ibm.com/
# - API: https://docs.quantum.ibm.com/api/qiskit
# - Repositorio: https://github.com/Qiskit
# - Instalación
# ```
#     pip install qiskit
#     pip install qiskit[visualization]
#     pip install qiskit==0.44.0
#
#     pip install qiskit-ibm-runtime
# ```

# %% [markdown]
# <a id="2.2"></a>
# ## 2.2. Cirq

# %% [markdown]
# Creado por Google, Cirq es un framework de Python para crear, editar y ejecutar circuitos cuánticos en simuladores cuánticos y hardware cuántico.
#
# - Página principal: https://quantumai.google/cirq
# - Tutoriales: https://quantumai.google/cirq/start/start
# - API: https://quantumai.google/reference/python/cirq/all_symbols
# - Repositorio: https://github.com/quantumlib/Cirq
# - Instalación
# ```
#     pip install cirq
# ```

# %% [markdown]
# <a id="2.3"></a>
# ## 2.3. PennyLane

# %% [markdown]
# Un framework de Xanadu que se centra en la computación cuántica híbrida clásica-cuántica y el Machine Learning Cuántico.
#
# - Página principal: https://pennylane.ai/
# - Tutoriales: https://pennylane.ai/qml/demonstrations/
# - API: https://docs.pennylane.ai/en/stable/code/qml.html
# - Repositorio: https://github.com/PennyLaneAI/pennylane
# - Instalación
# ```
#     pip install pennylane
# ```

# %% [markdown]
# <a id="2.4"></a>
# ## 2.4. Strawberry Fields

# %% [markdown]
# Otro framework de Xanadu para Python de full-stack para para diseñar, simular y optimizar circuitos ópticos cuánticos de variable continua.
#
# - Página principal: https://strawberryfields.ai/
# - Tutoriales: https://strawberryfields.ai/photonics/demonstrations.html
# - API: https://strawberryfields.readthedocs.io/en/stable/
# - Repositorio: https://github.com/XanaduAI/strawberryfields
# - Instalación
# ```
#     pip install strawberryfields
# ```

# %% [markdown]
# <a id="2.5"></a>
# ## 2.5. QuTiP

# %% [markdown]
# QuTiP (Quantum Toolbox in Python), creado por J.R. Johansson y P.D. Nation, está más enfocado en la simulación de sistemas cuánticos abiertos. QuTiP es ampliamente utilizado para estudios en computación cuántica y óptica cuántica.
#
# - Página principal: https://qutip.org/
# - Tutoriales: https://qutip.org/qutip-tutorials/
# - API: https://qutip.org/docs/latest/apidoc/apidoc.html
# - Repositorio: https://github.com/qutip/qutip
# - Instalación
# ```
#     pip install qutip
# ```

# %% [markdown]
# <a id="2.6"></a>
# ## 2.6. ProjectQ

# %% [markdown]
# Un framework de código abierto para computación cuántica en Python creado pro investigadores de la ETH Zúrich, permite implementar y ejecutar programas cuánticos en simuladores y hardware real de terceros (IBM, AWS Braket, Azure Quantum, IonQ).
#
# - Página principal: https://www.projectq.ch/ (inactiva)
# - Tutoriales: https://projectq.readthedocs.io/en/latest/tutorials.html
# - API: https://projectq.readthedocs.io/en/latest/projectq.html
# - Repositorio: https://github.com/ProjectQ-Framework/ProjectQ
# - Instalación
# ```
#     pip install projectq
# ```

# %% [markdown]
# <a id="2.7"></a>
# ## 2.7. Q#

# %% [markdown]
# Q# es un lenguaje de programación específico para la computación cuántica, y herramientas para escribir, simular y ejecutar programas cuánticos en diversos entornos. Es parte del Azure Quantum Development Kit (QDK). Q# es un lenguaje de programación por si mismo; si embargo, el QDK permite integrar programas Q# con Python.
#
# - Página principal: https://learn.microsoft.com/en-us/azure/quantum/user-guide/
# - Tutoriales: https://learn.microsoft.com/en-us/azure/quantum/tutorial-qdk-intro-to-katas
# - API: https://learn.microsoft.com/en-us/qsharp/api/qsharp/
# - Repositorio: https://github.com/microsoft/qsharp
# - Instalación (el QDK depende de .NET para ejecutar programas Q#)
# ```
#     pip install qsharp ipykernel
# ```
# ** Más detalles para la instalación: https://learn.microsoft.com/en-us/azure/quantum/install-overview-qdk

# %% [markdown]
# <a id="2.8"></a>
# ## 2.8. Amazon Braket SDK

# %% [markdown]
# Permite a los desarrolladores experimentar con computadoras cuánticas de diferentes proveedores (como D-Wave, IonQ, y Rigetti) a través de la nube de Amazon. Amazon Braket SDK está diseñado principalmente para ser utilizado con Python; sin embargo, recientemente ha hecho esfuerzos por proveer su SDK para otros lenguajes de programación como: .NET, C++, Go, Java, JavaScript, Ruby.
#
# - Página principal: https://docs.aws.amazon.com/braket/
# - Tutoriales: https://github.com/amazon-braket/amazon-braket-examples
# - API: https://docs.aws.amazon.com/braket/latest/APIReference/Welcome.html
# - Repositorio: https://github.com/amazon-braket/amazon-braket-sdk-python (el de Python)
# - Instalación
# ```
#     pip install amazon-braket-sdk
# ```

# %% [markdown]
# <a id="2.9"></a>
# ## 2.9. MindQuantum

# %% [markdown]
# MindQuantum, actualmente renombrado como MindSpore Quantum) es un framework de computación cuántica y machine learning cuántico desarrollado por Huawei. Forma parte de la plataforma MindSpore, que es un sistema de entrenamiento y computación de machine learning de código abierto también creado por Huawei.
#
# - Página principal: https://www.mindspore.cn/mindquantum/docs/en/master/index.html
# - Tutoriales: https://www.mindspore.cn/mindquantum/docs/en/master/beginner/beginner.html
# - API: https://www.mindspore.cn/mindquantum/docs/en/master/overview.html
# - Repositorio: https://github.com/mindspore-ai/mindquantum
# - Instalación
# ```
#     pip install mindquantum
# ```

# %% [markdown]
# <a id="3"></a>
# # 3. Plataformas con acceso a Hardware Cuántico

# %% [markdown]
# Varias plataformas ofrecen acceso a hardware cuántico, permitiendo a investigadores, desarrolladores y empresas experimentar con computación cuántica real. Algunas de estas plataformas se mencionan a contiuación.

# %% [markdown]
# <a id="3.1"></a>
# ## 3.1. IBM Quantum Platform

# %% [markdown]
# IBM Quantum Platform permite a los usuarios acceder a varias computadoras cuánticas a través de la nube. Utilizando el SDK Qiskit, los usuarios pueden crear y ejecutar circuitos cuánticos en hardware real o simuladores.
#
# Ofrece acceso a una variedad de procesadores cuánticos superconductores con diferentes cantidades de qubits.
#
# - Página principal: https://quantum.ibm.com/

# %% [markdown]
# <a id="3.2"></a>
# ## 3.2. Amazon Braket

# %% [markdown]
# Amazon Braket es un servicio de AWS que proporciona un entorno de desarrollo unificado para construir y probar algoritmos cuánticos. Ofrece acceso a computadoras cuánticas de diferentes proveedores.
#
# Incluye hardware de D-Wave (computación cuántica adiabática), IonQ (trampas de iones) y Rigetti (circuitos superconductores), IBM  (circuitos superconductores), entre otros.
#
# - Página principal: https://aws.amazon.com/braket/

# %% [markdown]
# <a id="3.3"></a>
# ## 3.3. Azure Quantum

# %% [markdown]
# Azure Quantum es la plataforma de Microsoft para computación cuántica en la nube, que proporciona acceso a hardware cuántico y simuladores cuánticos de varios colaboradores y proveedores.
#
# Colabora con proveedores como Honeywell y IonQ, ofreciendo tecnologías basadas en trampas de iones y otras implementaciones.
#
# - Página principal: https://quantum.microsoft.com/
#
# ** Lo malo: no se puede acceder desde México.</br>
# ** Lo bueno: una VPN nos permite acceder.

# %% [markdown]
# <a id="3.4"></a>
# ## 3.4. Google Quantum AI

# %% [markdown]
# Google Quantum AI trabaja en el desarrollo de procesadores cuánticos y algoritmos cuánticos. Aunque su acceso es más restringido comparado con otras plataformas, Google ha hecho avances significativos en la computación cuántica, como demostrar la ventaja cuántica. El acceso a las computadoras cuánticas de Google ha sido principalmente a través de colaboraciones académicas y de investigación, a diferencia de otras plataformas, Google no ha ofrecido un acceso público generalizado a sus computadoras cuánticas a través de la nube para individuos o empresas.
#
# Utiliza Procesadores cuánticos superconductores.
#
# - Página principal: https://quantumai.google/

# %% [markdown]
# <a id="3.5"></a>
# ## 3.5. Rigetti Quantum Cloud Services (QCS)

# %% [markdown]
# Rigetti ofrece una plataforma en la nube que permite a los usuarios acceder a sus computadoras cuánticas. Además, proporciona herramientas para el desarrollo de aplicaciones cuánticas.
#
# Su harware cuántico está basados en circuitos superconductores.
#
# - Página principal: https://www.rigetti.com/

# %% [markdown]
# <a id="3.6"></a>
# ## 3.6. IonQ

# %% [markdown]
# IonQ ofrece acceso a sus computadoras cuánticas a través de la nube, utilizando tecnología basada en trampas de iones. Sus sistemas están disponibles a través de Amazon Braket, Microsoft Azure Quantum y Google Cloud; no provee un acceso directo.
#
# Sus computadoras cuánticas están basadas en trampas de iones.
#
# - Página principal: https://ionq.com/

# %% [markdown]
# <a id="3.7"></a>
# ## 3.7. D-Wave Leap

# %% [markdown]
# D-Wave proporciona acceso en la nube a sus computadoras cuánticas adiabáticas, que están diseñadas específicamente para la optimización y problemas de muestreo.
#
# Hardware cuántico basado en la computación cuántica adiabática.
#
# - Página principal: https://www.dwavesys.com/solutions-and-products/cloud-platform/
#
# ** Lo malo: no se puede acceder desde México.</br>
# ** Lo bueno: una VPN nos permite acceder.

# %% [markdown]
# <a id="4"></a>
# # 4. Instalación y pruebas con Qiskit

# %% [markdown]
# Usaremos principalmnete **Qiskit** en las prácticas de esta clase debido a que es uno de los frameworks más populares en la comunidad de computación cuántica. Su popularidad se debe en gran parte a la accesibilidad del hardware cuántico de IBM a través de la nube, lo que permite a investigadores, estudiantes y entusiastas experimentar con computación cuántica real.

# %% [markdown]
# <a id="4.1"></a>
# ## 4.1. Repositorio

# %% [markdown]
# Los notebooks para los laboratorios estarán disponibles en el siguiente repositorio:
#
#     https://github.com/clausia/cursofi-computacion-cuantica

# %% [markdown]
# <a id="4.2"></a>
# ## 4.2. Instalación local

# %% [markdown]
# ### Anaconda
#
# La recomendación es usar Anaconda como administrador de ambientes de desarrollo.
#
# - Página principal: https://www.anaconda.com/
# - Instrucciones de instalación: https://docs.anaconda.com/free/anaconda/install/index.html
#
# Se pueden usar otros administradores de entornos, es una elección personal: [virtualenv](https://virtualenv.pypa.io/en/latest/), [Pipenv](https://pipenv.pypa.io/en/latest/), [Poetry](https://python-poetry.org/), [Conda](https://docs.conda.io/en/latest/), [Docker](https://www.docker.com/), etc.
#
# ### Crear entorno
#
# ```
#     conda create -n ccuantica python=3.11
# ```
#
# El nombre del ambiente es de elección libre, aquí se sugiere `ccuantica`.
#
# La versión de Python no es libre, se debe usar `3.11` para evitar problemas de compatibilidad.
#
# ### Iniciar entorno
#
# ```
#     conda activate ccuantica
# ```
#
# ### Instalar Qiskit
#
# ```
#     pip install qiskit[visualization]==0.44.0
# ```
#
# Por ahora usaremos esta versión en particular, ya que los ejemplos existentes entre la comunidad son compatibles con esta versión.
#
# En los iguientes días (febrero 2024), Qiskit 1.0 será liberado y no será retrocompatible con las versiones anteriores.
#
# ### Instalar Jupyter
#
# Es posible que se instale Jupyter con la instalación de Qiskit, lo que se puede comprobar con:
#
# ```
#     pip list
# ```
#
# Si no se instaló, hacerlo:
#
# ```
#     pip install jupyter
# ```

# %% [markdown]
# <a id="4.3"></a>
# ## 4.3. Ejemplos en Qiskit

# %% [markdown]
# En el siguiente ejemplo se define un circuito cuántico con 3 qubits, también se definen 2 bits clásicos (líneas dobles), y se aplican 3 compuertas cuánticas. Veremos el detalle de cada uno de estos elementos más adelante.
#
# Si el siguiente código funciona, entonces el entorno local ya está listo.

# %%
# Código Ejemplo 1:

from qiskit import QuantumCircuit

circ = QuantumCircuit(3, 2) # circuito con 3 qubits y 2 bits clásicos

circ.h(0)           # aplicar compuerta H al qubit 0
circ.cx(0, 1)       # aplicar compuerta CNOT a los qubits 0 y 1
circ.cx(0, 2)       # aplicar compuerta CNOT a los qubits 0 y 2
circ.measure(0, 1)  # medir el qubit 0 en el bit clásico 1
circ.measure(2, 0)  # medir el qubit 2 en el bit clásico 0

circ.draw('mpl')    # mostrar el circuito

# %% [markdown]
# Un ejemplo mucho más sencillo: implica un solo qubit, y una sola compuerta cuántica:

# %%
# Código Ejemplo 2:

from qiskit.quantum_info import Statevector
from qiskit.visualization import array_to_latex
from qiskit.visualization import plot_bloch_multivector


circ1 = QuantumCircuit(1)    # circuito con 1 qubit

psi_0 = Statevector(circ1)   # estado justo después de crear el circuito

circ1.x(0)                   # aplicar compuerta X al (único) qubit 0

psi_1 = Statevector(circ1)   # estado después aplicar la compuerta X

display(circ1.draw('mpl'))   # mostrar el circuito

print("👉 Estado inicial:")
print("➤ en forma de vector:")
display(array_to_latex(psi_0.data))
print("➤ en forma de ket:")
display(psi_0.draw('latex'))
print()

print("👉 Estado después de X:")
print("➤ en forma de vector:")
display(array_to_latex(psi_1.data))
print("➤ en forma de ket:")
display(psi_1.draw('latex'))

print("👉 Representación con la esfera de Bloch:")
print("🔵 Estado inicial:")
display(plot_bloch_multivector(psi_0))

print("🔵 Estado después de X:")
display(plot_bloch_multivector(psi_1))
# Out:
# 👉 Estado inicial:
# ➤ en forma de vector:
# $$
#
# \begin{bmatrix}
# 1 & 0  \\
#  \end{bmatrix}
# $$
# ➤ en forma de ket:
# $$ |0\rangle$$
# 👉 Estado después de X:
# ➤ en forma de vector:
# $$
#
# \begin{bmatrix}
# 0 & 1  \\
#  \end{bmatrix}
# $$
# ➤ en forma de ket:
# $$ |1\rangle$$
# 👉 Representación con la esfera de Bloch:
# 🔵 Estado inicial:
# 🔵 Estado después de X:

# %% [markdown]
# Ahora una versión simplificada que muestra el estado del qubit en una esfera de Bloch, después de aplicar una sola compuerta cuántica (la compuerta `H`).

# %%
# Código Ejemplo 3:

circ2 = QuantumCircuit(1)
circ2.h(0) 

display(plot_bloch_multivector(Statevector(circ2)))

# %%
# Código Ejemplo 4:

from qiskit.primitives import Sampler
from qiskit.visualization import plot_histogram

circ2.measure_all()

sampler = Sampler()
job2 = sampler.run(circ2)

legend = ["Resultado de circ2"]
plot_histogram([job2.result().quasi_dists[0]], legend=legend)

# %% [markdown]
# Otro ejemplo con dos qubits y la generación de la _superposición_ de los mismos:

# %%
# Código Ejemplo 5:

circ3 = QuantumCircuit(2, 2)

circ3.h(0)
circ3.h(1)

display(circ3.draw('mpl'))

circ3.measure(0, 0)
circ3.measure(1, 1)

job3 = Sampler().run(circ3)

plot_histogram([job3.result().quasi_dists[0].binary_probabilities()], legend=["Resultado de circ3"])

# %% [markdown]
# <a id="4.5"></a>
# ## 4.5. Cuenta en IBM Quantum Platform

# %% [markdown]
# Crear una cuenta en la [IBM Quantum Platform](https://quantum.ibm.com/), es gratis y nos permitirá:
#
# - Acceder a las computadoras cuánticas de IBM:  https://quantum.ibm.com/services/resources
# - Usar un servidor Jupyter online: https://quantum.ibm.com/lab
# - Usar una herramienta visual para hacer circuito cuánticos (IBM Quantum Composer): https://quantum.ibm.com/composer

# %% [markdown]
# <a id="5"></a>
# # 5. Computadoras SpinQ

# %% [markdown]
# Las computadoras cuánticas SpinQ son creadas por **[Shenzhen SpinQ Technology Co., Ltd](https://www.spinquanta.com/)**, una empresa que se especializa en el desarrollo de hardware y software para computación cuántica. SpinQ Technology tiene sus raíces en la investigación académica y se ha centrado en la creación de computadoras cuánticas de escritorio accesibles, destinados principalmente para fines educativos y de investigación a pequeña escala.
#
# La empresa, originaria de China, ha estado a la vanguardia de hacer la tecnología cuántica más accesible para instituciones educativas, investigadores y estudiantes, ofreciendo dispositivos cuánticos relativamente asequibles. Estos dispositivos están diseñados para proporcionar una plataforma práctica para la enseñanza y el aprendizaje de la computación cuántica, permitiendo a los usuarios realizar experimentos cuánticos reales y aprender sobre principios cuánticos fundamentales sin necesitar acceso a instalaciones de investigación de alta gama.
#
# SpinQ ha lanzado varias versiones de sus computadoras cuánticas de escritorio, incluidos modelos basados en tecnología de [resonancia magnética nuclear (RMN)](https://en.wikipedia.org/wiki/Nuclear_magnetic_resonance) como lo son los dispositivos que se encuentran en este laboratorio.

# %% [markdown]
# <a id="5.1"></a>
# ## 5.1. Ejemplos en SpinQ

# %% [markdown]
# ### Ejemplo 1: Cambio de estado
#
# 1 qubit</br>
# Compuerta: `X`

# %% [markdown]
# <img width="700"
# src="data:image/png;base64,..."/>

# %% [markdown]
# ### Ejemplo 2: Superposición
#
# 1 qubit</br>
# Compuerta: `H`

# %% [markdown]
# <img width="700" src="data:image/png;base64,..."/>

# %% [markdown]
# ### Ejemplo 3: Superposición
#
# 2 qubits</br>
# Compuertas: `H` $\otimes$ `H`

# %% [markdown]
# <img width="700" src="data:image/png;base64,..."/>

# %% [markdown]
# <a id="6"></a>
# # 6. Tarea

# %% [markdown]
# La Tarea deberá ser entregada en un Jupyter notebook, debe ser uno nuevo (no se puede usar este), el archivo debe ser subido al Google Classroom y debe contener todas las instrucciones necesarias para ejecutarlo si es que se requieren otras además de las vistas para este notebook.
#
# 1. Crear una cuenta en la [IBM Quantum Platform](https://quantum.ibm.com/), para mostrar evidencia de esta actividad se deberá incluir una imagen en el notebook a entregar del [Dashboard](https://quantum.ibm.com/) en donde se vea su nombre. _Si la imagen no se ve, porque no fue agregada correctamente, entonces no se tomará como completado este paso._
# 2. Reproducir el **Código Ejemplo 1** en el [IBM Quantum Composer](https://quantum.ibm.com/composer), incluir un pantallazo del resutado en el notebook a entregar. _Si la imagen no se ve, porque no fue agregada correctamente, entonces no se tomará como completado este paso._
# 3. Reproducir los siguientes ejemplos de código en otro framework distinto a Qiskit, pueden elegir el que quieran de los mencionados en este notebook:
#  - Código Ejemplo 1: mostrar el circuito cuántico
#  - Código Ejemplo 3: mostrar la esfera de Bloch
#  - Código Ejemplo 5: mostrar circuito cuántico e histograma
#
# **Nota**: Esta tarea es individual.
